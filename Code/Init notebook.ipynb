# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting xgboost==1.7.5
#   Downloading xgboost-1.7.5-py3-none-manylinux2014_x86_64.whl (200.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.3/200.3 MB 8.0 MB/s eta 0:00:00
# Collecting streamlit==1.21.0
#   Downloading streamlit-1.21.0-py2.py3-none-any.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 60.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from xgboost==1.7.5->-r ./requirements.txt (line 1)) (1.23.4)
# Requirement already satisfied: scipy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from xgboost==1.7.5->-r ./requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: pandas<2,>=0.25 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.21.0->-r ./requirements.txt (line 3)) (1.2.5)
# Requirement already satisfied: importlib-metadata>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.21.0->-r ./requirements.txt (line 3)) (5.0.0)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 KB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: tzlocal>=1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.21.0->-r ./requirements.txt (line 3)) (4.2)
# Requirement already satisfied: requests>=2.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.21.0->-r ./requirements.txt (line 3)) (2.28.1)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting watchdog
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 KB 15.7 MB/s eta 0:00:00
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting rich>=10.11.0
#   Downloading rich-13.3.4-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 KB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: cachetools>=4.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.21.0->-r ./requirements.txt (line 3)) (5.2.0)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.21.0->-r ./requirements.txt (line 3)) (9.2.0)
# Requirement already satisfied: python-dateutil in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit==1.21.0->-r ./requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.21.0->-r ./requirements.txt (line 3)) (4.4.0)
# Requirement already satisfied: altair<5,>=3.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.21.0->-r ./requirements.txt (line 3)) (4.2.2)
# Requirement already satisfied: tornado>=6.0.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit==1.21.0->-r ./requirements.txt (line 3)) (6.2)
# Requirement already satisfied: protobuf<4,>=3.12 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.21.0->-r ./requirements.txt (line 3)) (3.19.6)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 26.9 MB/s eta 0:00:00
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 54.9 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=4.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.21.0->-r ./requirements.txt (line 3)) (9.0.0)
# Requirement already satisfied: click>=7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from streamlit==1.21.0->-r ./requirements.txt (line 3)) (8.1.3)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: packaging>=14.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from streamlit==1.21.0->-r ./requirements.txt (line 3)) (21.3)
# Requirement already satisfied: entrypoints in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair<5,>=3.2.0->streamlit==1.21.0->-r ./requirements.txt (line 3)) (0.4)
# Requirement already satisfied: toolz in /shared-libs/python3.9/py/lib/python3.9/site-packages (from altair<5,>=3.2.0->streamlit==1.21.0->-r ./requirements.txt (line 3)) (0.12.0)
# Requirement already satisfied: jinja2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair<5,>=3.2.0->streamlit==1.21.0->-r ./requirements.txt (line 3)) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from altair<5,>=3.2.0->streamlit==1.21.0->-r ./requirements.txt (line 3)) (3.2.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-metadata>=1.4->streamlit==1.21.0->-r ./requirements.txt (line 3)) (3.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=14.1->streamlit==1.21.0->-r ./requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas<2,>=0.25->streamlit==1.21.0->-r ./requirements.txt (line 3)) (2022.5)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil->streamlit==1.21.0->-r ./requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.21.0->-r ./requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.21.0->-r ./requirements.txt (line 3)) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.21.0->-r ./requirements.txt (line 3)) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.21.0->-r ./requirements.txt (line 3)) (3.4)
# Collecting markdown-it-py<3.0.0,>=2.2.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from rich>=10.11.0->streamlit==1.21.0->-r ./requirements.txt (line 3)) (2.13.0)
# Requirement already satisfied: pytz-deprecation-shim in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tzlocal>=1.1->streamlit==1.21.0->-r ./requirements.txt (line 3)) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from validators>=0.2->streamlit==1.21.0->-r ./requirements.txt (line 3)) (5.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2->altair<5,>=3.2.0->streamlit==1.21.0->-r ./requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.21.0->-r ./requirements.txt (line 3)) (22.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.21.0->-r ./requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.21.0->-r ./requirements.txt (line 3)) (58.1.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: tzdata in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit==1.21.0->-r ./requirements.txt (line 3)) (2022.5)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py): started
#   Building wheel for validators (setup.py): finished with status 'done'
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19581 sha256=cbede8f1bb0d5d76354be88d1c8ba6b818a9c216522ef4ce4e3a85f2c44f473f
#   Stored in directory: /root/.cache/pip/wheels/2d/f0/a8/1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built validators
# Installing collected packages: watchdog, validators, toml, smmap, pympler, mdurl, blinker, xgboost, pydeck, markdown-it-py, gitdb, rich, gitpython, streamlit
# Successfully installed blinker-1.6.2 gitdb-4.0.10 gitpython-3.1.31 markdown-it-py-2.2.0 mdurl-0.1.2 pydeck-0.8.1b0 pympler-1.0.1 rich-13.3.4 smmap-5.0.0 streamlit-1.21.0 toml-0.10.2 validators-0.20.0 watchdog-3.0.0 xgboost-1.7.5
# WARNING: You are using pip version 22.0.4; however, version 23.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=762520ba-b8cf-4151-96d5-65e8763600e9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
